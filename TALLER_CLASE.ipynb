# %%
import pandas as pd
import os
datos = pd.read_excel('/content/drive/MyDrive/DIPLOMADO/TALLER modulo 1/DATOS/BaseEVA_Agrícola20192022.xlsx')
if not os.path.exists("/content/drive/MyDrive/DIPLOMADO/TALLER modulo 1/Resultados"): os.makedirs("/content/drive/MyDrive/DIPLOMADO/TALLER modulo 1/Resultados")
datos_p = datos.copy()
datos_filtrados = datos_p[(datos_p['Departamento'] =="Meta")]
datos_filtrados.to_excel("/content/drive/MyDrive/DIPLOMADO/TALLER modulo 1/Resultados/datos_completos meta.xlsx", index=False)

# %%
etiquetas_genero = datos_p['Desagregación cultivo'].nunique()
print(f"LOS CULTIVOS SON LOS SIGUIENTES: {etiquetas_genero}")
# Out:
# LOS CULTIVOS SON LOS SIGUIENTES: 190

# %%
datos_filtrados = datos_p[(datos_p['Departamento'] =="Meta")]
datos_filtrados = datos_filtrados[['Municipio','Desagregación cultivo', 'Año','Área cosechada (ha)','Producción (t)','Rendimiento (t/ha)']]
datos_filtrados.to_excel("/content/drive/MyDrive/DIPLOMADO/TALLER modulo 1/Resultados/datos_filtrados columna meta.xlsx", index=False)
datos_filtrados
# Out:
#            Municipio      Desagregación cultivo   Año  Área cosechada (ha)  \
# 9705   Villavicencio                  Guanábana  2019                101.0
# 9706   Villavicencio                    Guayaba  2019                 83.0
# 9707   Villavicencio      Piña demás variedades  2019                759.0
# 9708   Villavicencio    Plátano consumo interno  2019                219.0
# 9709   Villavicencio             Otros cítricos  2019               1590.0
# ...              ...                        ...   ...                  ...
# 88516   Vistahermosa  Maíz Amarillo Tecnificado  2022                820.0
# 88517   Vistahermosa  Maíz Amarillo Tradicional  2022                 16.0
# 88518   Vistahermosa    Arroz Secano Mecanizado  2022               2301.0
# 88519   Vistahermosa  Maíz Amarillo Tecnificado  2022                140.0
# 88520   Vistahermosa  Maíz Amarillo Tradicional  2022                 27.0
#
#        Producción (t)  Rendimiento (t/ha)
# ...

# %%
datos_p = datos.copy()
datos_filtrados = datos_p[(datos_p['Departamento'] =="Meta")]
datos_orden_area = datos_filtrados.sort_values(by= 'Área cosechada (ha)', ascending = False)
datos_orden_area.to_excel("/content/drive/MyDrive/DIPLOMADO/TALLER modulo 1/Resultados/datos_filtrados cosecha mayormenor.xlsx", index=False)

# %%
datos_filtrados.isnull().sum()
# Out:
# Código Dane departamento         0
# Departamento                     0
# Código Dane municipio            0
# Municipio                        0
# Desagregación cultivo            0
# Cultivo                          0
# Ciclo del cultivo                0
# Grupo cultivo                    0
# Subgrupo                         0
# Año                              0
# Periodo                          0
# Área sembrada (ha)               0
# Área cosechada (ha)              0
# Producción (t)                   0
# Rendimiento (t/ha)               0
# Código del cultivo               0
# Nombre científico del cultivo    0
# Estado físico del cultivo        0
# dtype: int64

# %%
datos_filtrados = datos_p.fillna("Desconocido")
datos_filtrados.to_excel("/content/drive/MyDrive/DIPLOMADO/TALLER modulo 1/Resultados/filtrados con deconocido.xlsx", index=False)
datos_filtrados.isnull().sum()
# Out:
# Exception ignored in: <function ZipFile.__del__ at 0x7c94cb122200>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/zipfile.py", line 1821, in __del__
#     self.close()
#   File "/usr/lib/python3.10/zipfile.py", line 1838, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file
# Código Dane departamento         0
# Departamento                     0
# Código Dane municipio            0
# Municipio                        0
# Desagregación cultivo            0
# Cultivo                          0
# Ciclo del cultivo                0
# Grupo cultivo                    0
# Subgrupo                         0
# Año                              0
# Periodo                          0
# Área sembrada (ha)               0
# Área cosechada (ha)              0
# Producción (t)                   0
# Rendimiento (t/ha)               0
# Código del cultivo               0
# Nombre científico del cultivo    0
# Estado físico del cultivo        0
# ...

# %%
datos_orden_area = datos_filtrados.sort_values(by= 'Rendimiento (t/ha)', ascending = False)
datos_orden_area.to_excel("/content/drive/MyDrive/DIPLOMADO/TALLER modulo 1/Resultados/rendimiento mayor.xlsx", index=False)
